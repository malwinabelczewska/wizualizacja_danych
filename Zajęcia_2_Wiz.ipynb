# %% [markdown]
# x1=np.array([1,2,3])
# y1=np.array([2,2,1])

# %%
plt.scatter(x1,y1, marker='o')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 plt.scatter(x1,y1, marker='o')
#
# NameError: name 'x1' is not defined

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
plt.show()

# %%
x1=np.array([1,2,3]) 
y1=np.array([2,2,1])
plt.scatter(x1,y1, marker='h')
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot()
ax.scatter([2,4,6],[5,15,25],
          color='green',
          marker='^')
ax.set_xlim(1.5,6.5)
plt.savefig('wynik1.pdf')
plt.show()

# %%
fig, ax=plt.subplots()
x=np.linspace(0,20,1000)
ax.plot(x,np.cos(x))
ax.axis('equal')
ax.annotate('lokalne maksimum', xy=(2*np.pi,1),xytext=(10,4),
           arrowprops=dict(facecolor='red', shrink=0.05))
ax.annotate('lokalne minimum', xy=(5*np.pi,-1),xytext=(2,-6),
            arrowprops=dict(arrowstyle='<->',connectionstyle="angle3,angleA=0,angleB=-90"))
# Out:
# Text(2, -6, 'lokalne minimum')

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(-3,3,1000)
y=x**3-x**2-3*x+5
fig=plt.figure()
ax=fig.add_subplot()
ax.spines['left'].set_position('center')
ax.spines['bottom'].set_position('center')
ax.spines['right'].set_color('none')
ax.set_ylim(-10,8)
ax.set_xlim(-3,3)
ax.grid(True)
ax.plot(x,y,color='green')
plt.title(r"Wykres funkcji $f(x)=x**3-x**2-3*x+5$")
plt.xlabel("$x$",fontsize=10)
plt.ylabel("$f(x)$",fontsize=10)
# Out:
# Text(0, 0.5, '$f(x)$')

# %%
x=np.linspace(-3,3,1000)
fig=plt.figure()
y=8*x**4-14*x**3-9*x**2+11*x-1

fig, ax=plt.subplots(figsize=(8,5))
ax.set_xlim(-2,3)
ax.set_ylim(-12,6)

def fun1(x):
    y=8*x**4-14*x**3-9*x**2+11*x-1
    return y
    
x1=np.array([-0.59159159,  0.38138138,  1.53453453])
y1=np.array([fun1(-0.59159159),fun1(0.38138138),fun1(1.53453453)])
plt.scatter(x1,y1,color='white',zorder=3) #na której warstwie rysowany jest obiekt
ax.set_xticks(stacj1) # punkty stacjonarne zaznaczone na osi x


ax.grid(True)
ax.set_facecolor('black')
plt.plot(x,y)

dydx=np.gradient(y,x)
stacj1=x[1:][dydx[1:]*dydx[:-1]<0] #punkty stacjonarne


colors=['green' if y[i]>y[i-1] else 'red' for i in range(1,len(y))] #lista kolorów
for i in range(1,len(y)): #rysowanie wykresu
    ax.plot([x[i-1],x[i]],[y[i-1],y[i]],color=colors[i-1]) 


#plt.show()
stacj1
# Out:
# array([-0.59159159,  0.38138138,  1.53453453])

# %%
def fun1(x):
    y=8*x**4-14*x**3-9*x**2+11*x-1
    return y

# %%
punktyST=[(x,fun1(x))for x in stacj1]
punktyST
# Out:
# [(np.float64(-0.5915915915915915), np.float64(-6.778803367091598)),
#  (np.float64(0.38138138138138133), np.float64(1.2787627901988268)),
#  (np.float64(1.5345345345345347), np.float64(-11.541989770478704))]
